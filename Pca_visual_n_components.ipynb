# %%
from sklearn.decomposition import PCA

pca_ic = PCA(n_components=2)
X_pca_ic = pca_ic.fit_transform(X_new_ic)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca_ic[:, 0], y=X_pca_ic[:, 1], hue=clusters, palette='viridis', s=60)
plt.title("PCA визуализация кластеров (IC50)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(title="Кластер")
plt.grid(True)
plt.tight_layout()
plt.show()

pca_components_ic = pd.DataFrame(
    pca_ic.components_,
    columns = feature_names_ic,
    index = ['PC1', 'PC2']
)

# Вклад признаков
print(pca_components_ic.T.sort_values(by='PC1', ascending=False))
# Out:
#                               PC1       PC2
# Chi0                     0.233461  0.001037
# NumValenceElectrons      0.233389  0.023674
# LabuteASA                0.232945  0.021156
# ExactMolWt               0.232834 -0.010940
# MolWt                    0.232803 -0.010979
# Chi1                     0.232270 -0.004836
# HeavyAtomMolWt           0.230601 -0.031875
# Kappa1                   0.229712  0.023783
# Chi0v                    0.226790  0.070921
# MolMR                    0.226275  0.052919
# Chi0n                    0.224774  0.079516
# Kappa2                   0.217176 -0.011049
# BertzCT                  0.205478 -0.078240
# Chi2v                    0.185085  0.171402
# Kappa3                   0.182011 -0.030277
# AvgIpc                   0.181683 -0.026999
# SlogP_VSA2               0.164567 -0.033234
# PEOE_VSA9                0.146389 -0.001290
# SMR_VSA1                 0.139408 -0.155333
# PEOE_VSA1                0.128801 -0.106438
# ...

# %%
pca_cc = PCA(n_components=2)
X_pca_cc = pca_cc.fit_transform(X_new_cc)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca_cc[:, 0], y=X_pca_cc[:, 1], hue=clusters_cc, palette='viridis', s=60)
plt.title("PCA визуализация кластеров (CC50)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(title="Кластер")
plt.grid(True)
plt.tight_layout()
plt.show()

pca_components_сc = pd.DataFrame(
    pca_cc.components_,
    columns = feature_names_cc,
    index = ['PC1', 'PC2']
)

# Вклад признаков
print(pca_components_сc.T.sort_values(by = 'PC1', ascending=False))
# Out:
#                           PC1       PC2
# LabuteASA            0.212078 -0.006200
# NumValenceElectrons  0.211352 -0.004269
# HeavyAtomCount       0.210608 -0.030011
# Chi0                 0.210347 -0.029178
# Chi1                 0.209883 -0.033609
# Chi0v                0.209511  0.046250
# ExactMolWt           0.209220 -0.038541
# MolWt                0.209190 -0.038552
# MolMR                0.209186  0.027078
# Chi0n                0.207992  0.053490
# Kappa1               0.207425 -0.004304
# HeavyAtomMolWt       0.205983 -0.059822
# Chi1v                0.204966  0.073637
# Chi1n                0.203246  0.084012
# Kappa2               0.194792 -0.036069
# BertzCT              0.182655 -0.106958
# Chi2v                0.178444  0.153905
# Chi2n                0.173275  0.169409
# AvgIpc               0.165881 -0.042375
# Kappa3               0.161566 -0.051843
# Chi3v                0.157687  0.187112
# Chi3n                0.150574  0.202536
# ...

# %%
pca_si = PCA(n_components=2)
X_pca_si = pca_si.fit_transform(X_new_si)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca_si[:, 0], y=X_pca_si[:, 1], hue=clusters_si, palette='viridis', s=60)
plt.title("PCA визуализация кластеров (SI)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(title="Кластер")
plt.grid(True)
plt.tight_layout()
plt.show()

pca_components_si = pd.DataFrame(
    pca_si.components_,
    columns = feature_names_si,
    index = ['PC1', 'PC2']
)

#Вклад признаков
print(pca_components_si.T.sort_values(by = 'PC1', ascending = False))
# Out:
#                               PC1       PC2
# BertzCT                  0.216975  0.119761
# MaxPartialCharge         0.203834 -0.019882
# MinAbsPartialCharge      0.203680 -0.009655
# MaxAbsEStateIndex        0.203548 -0.025242
# MaxEStateIndex           0.203548 -0.025242
# SlogP_VSA6               0.197640  0.013084
# BCUT2D_MWLOW             0.187851 -0.125464
# Kappa2                   0.179701  0.187596
# LabuteASA                0.171400  0.214495
# VSA_EState2              0.171293  0.087112
# AvgIpc                   0.168376  0.139393
# Kappa3                   0.166392  0.147811
# Kappa1                   0.165880  0.218086
# EState_VSA1              0.145113 -0.007050
# BCUT2D_CHGLO             0.144418 -0.139754
# SlogP_VSA2               0.134435  0.133313
# PEOE_VSA2                0.126407  0.101265
# Chi0n                    0.126084  0.247529
# EState_VSA9              0.121139  0.056988
# BCUT2D_MRHI              0.113228 -0.013830
# ...

# %% [markdown]
# Судя по визуализации кластеров, 0 кластер совпадает практически везде, поэтому он остается стабильным и менее информативным для задачи разработки лекарств. Однако кластеры 1 и 2 более "гибкие": на графиках явно видны их изменения, особенно у второго кластера, который занимает разные стороны относительно 0. Анализируя данный вывод вместе с другими, можно сделать предположение о том, что деление на кластеры действительно способствует лучшему предсказанию эффективности различных соединений: кластер 0 остается более стабильным, кластеры 1 и 2 меняются. Второй кластер наиболее информативен для задач регрессии, а первый кластер лучшего всего подходит для того, чтобы понимать, превышает ли значение IC50, CC50 и SI медиану или 8 (в случае SI). Это довольно важное наблюдение, которое поможет облегчить работу при анализе данных показателей при разработке лекарств.
# Также ниже графиков представлены признаки и их вклад в компоненты.
